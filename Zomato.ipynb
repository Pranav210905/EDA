# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('zomato.csv', skiprows=range(30484, 30500))
data
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 30478  https://www.zomato.com/bangalore/the-biriyani-...
# 30479  https://www.zomato.com/bangalore/berryd-alive-...
# 30480  https://www.zomato.com/bangalore/priyas-punjab...
# 30481  https://www.zomato.com/bangalore/guns-n-roses-...
# 30482  https://www.zomato.com/bangalore/sagar-fast-fo...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30483 entries, 0 to 30482
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          30483 non-null  object
#  1   address                      30483 non-null  object
#  2   name                         30483 non-null  object
#  3   online_order                 30483 non-null  object
#  4   book_table                   30483 non-null  object
#  5   rate                         25974 non-null  object
#  6   votes                        30483 non-null  int64
#  7   phone                        29856 non-null  object
#  8   location                     30474 non-null  object
#  9   rest_type                    30344 non-null  object
#  10  dish_liked                   13740 non-null  object
#  11  cuisines                     30459 non-null  object
#  12  approx_cost(for two people)  30344 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.shape
# Out:
# (30483, 17)

# %%
data.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            4509
# votes                              0
# phone                            627
# location                           9
# rest_type                        139
# dish_liked                     16743
# cuisines                          24
# approx_cost(for two people)      139
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#remove
data.drop(['url','address','dish_liked','phone','menu_item'],axis=1,inplace=True)

# %%
data
# Out:
#                         name online_order book_table    rate  votes  \
# 0                      Jalsa          Yes        Yes   4.1/5    775
# 1             Spice Elephant          Yes         No   4.1/5    787
# 2            San Churro Cafe          Yes         No   3.8/5    918
# 3      Addhuri Udupi Bhojana           No         No   3.7/5     88
# 4              Grand Village           No         No   3.8/5    166
# ...                      ...          ...        ...     ...    ...
# 30478   The Biriyani Factory          Yes         No  3.1 /5     30
# 30479          Berry'd Alive          Yes         No  4.3 /5   1902
# 30480        Priya's Punjabi           No         No  3.8 /5     33
# 30481           Guns N Roses          Yes         No  3.6 /5     23
# 30482        Sagar Fast Food          Yes         No  3.7 /5     67
#
#                     location            rest_type  \
# 0               Banashankari        Casual Dining
# ...

# %%
data.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           4509
# votes                             0
# location                          9
# rest_type                       139
# cuisines                         24
# approx_cost(for two people)     139
# reviews_list                      0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people)  \
# 0                         800
# 1                         800
# 2                         800
# 3                         300
# ...

# %%
#rename columns
data.rename(columns={"name":"reasturant",
                     "rate":"rating",
                     "cuisines":"food_type",
                     "listed_in(type)":"type",
                     "listed_in(city)":"city",
                     "approx_cost(for two people)":"cost"},inplace=True)

# %%
data.head()
# Out:
#               reasturant online_order book_table rating  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1/5    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8/5    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88  Banashankari
# 4          Grand Village           No         No  3.8/5    166  Basavanagudi
#
#              rest_type                       food_type cost  \
# 0        Casual Dining  North Indian, Mughlai, Chinese  800
# 1        Casual Dining     Chinese, North Indian, Thai  800
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian  800
# 3          Quick Bites      South Indian, North Indian  300
# 4        Casual Dining        North Indian, Rajasthani  600
#
#                                         reviews_list    type          city
# ...

# %%
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (25770, 12)

# %%
#clean indvidual columns
# Out:
#                                               online_order  book_table  \
# reasturant
# #FeelTheROLL                                             1           1
# #L-81 Cafe                                               6           6
# #refuel                                                  3           3
# 1000 B.C                                                 4           4
# 100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C                     3           3
# ...                                                    ...         ...
# i-Bar - The Park Bangalore                               6           6
# iFruit Live Ice Creams                                   1           1
# iSpice Resto Cafe                                        3           3
# nu.tree                                                  3           3
# re:cess - Hilton Bangalore Embassy GolfLinks             1           1
#
#                                               rating  votes  location  \
# reasturant
# ...

# %%
data.online_order.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data.book_table.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data.reasturant.unique()
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ...,
#        'Sizzling Tandoor', '99 Variety Dosa & Pav Bhaji',
#        'Big Fat Brownie'], dtype=object)

# %%
data.rating.unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ',
#        '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ',
#        '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 '],
#       dtype=object)

# %%
replace = lambda x:x.replace('/5',"")
l=[]
for val in map(replace,data['rating']):
    if val!="NEW" and val!="-":
        var=float(val)
    l.append(val)
data['rating'] = l

# %%
data.head()
# Out:
#               reasturant online_order book_table rating  votes      location  \
# 0                  Jalsa          Yes        Yes    4.1    775  Banashankari
# 1         Spice Elephant          Yes         No    4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No    3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No    3.7     88  Banashankari
# 4          Grand Village           No         No    3.8    166  Basavanagudi
#
#              rest_type                       food_type cost  \
# 0        Casual Dining  North Indian, Mughlai, Chinese  800
# 1        Casual Dining     Chinese, North Indian, Thai  800
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian  800
# 3          Quick Bites      South Indian, North Indian  300
# 4        Casual Dining        North Indian, Rajasthani  600
#
#                                         reviews_list    type          city
# ...

# %%
data.votes.isnull().value_counts()
# Out:
# votes
# False    25770
# Name: count, dtype: int64

# %%
data.location.unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Bannerghatta Road', 'BTM', 'Kanakapura Road', 'Bommanahalli',
#        'CV Raman Nagar', 'Electronic City', 'Wilson Garden',
#        'Shanti Nagar', 'Koramangala 5th Block', 'Richmond Road', 'HSR',
#        'Marathahalli', 'Koramangala 7th Block', 'Bellandur',
#        'Sarjapur Road', 'Whitefield', 'East Bangalore',
#        'Old Airport Road', 'Indiranagar', 'Koramangala 1st Block',
#        'Frazer Town', 'MG Road', 'Brigade Road', 'Lavelle Road',
#        'Church Street', 'Ulsoor', 'Residency Road', 'Shivajinagar',
#        'Infantry Road', 'St. Marks Road', 'Cunningham Road',
#        'Race Course Road', 'Commercial Street', 'Vasanth Nagar', 'Domlur',
#        'Koramangala 8th Block', 'Ejipura', 'Jeevan Bhima Nagar',
# ...

# %%
data.rest_type.unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Dessert Parlor, Sweet Shop', 'Bakery, Quick Bites',
#        'Sweet Shop, Quick Bites', 'Kiosk', 'Food Truck',
#        'Quick Bites, Dessert Parlor', 'Beverage Shop, Quick Bites',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Microbrewery, Casual Dining', 'Lounge',
#        'Bar, Casual Dining', 'Food Court', 'Cafe, Bakery', 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
#        'Food Court, Quick Bites', 'Quick Bites, Beverage Shop',
#        'Pub, Bar', 'Casual Dining, Pub', 'Lounge, Bar',
# ...

# %%
data.food_type.unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ...,
#        'North Indian, Chinese, Rolls, Fast Food', 'Bakery, Sandwich',
#        'Fast Food, Street Food, North Indian, Biryani'], dtype=object)

# %%
data.reviews_list.unique()
# Out:
# array(['[(\'Rated 4.0\', \'RATED\\n  A beautiful place to dine in.The interiors take you back to the Mughal era. The lightings are just perfect.We went there on the occasion of Christmas and so they had only limited items available. But the taste and service was not compromised at all.The only complaint is that the breads could have been better.Would surely like to come here again.\'), (\'Rated 4.0\', \'RATED\\n  I was here for dinner with my family on a weekday. The restaurant was completely empty. Ambience is good with some good old hindi music. Seating arrangement are good too. We ordered masala papad, panner and baby corn starters, lemon and corrionder soup, butter roti, olive and chilli paratha. Food was fresh and good, service is good too. Good for family hangout.\\nCheers\'), (\'Rated 2.0\', \'RATED\\n  Its a restaurant near to Banashankari BDA. Me along with few of my office friends visited to have buffet but unfortunately they only provide veg buffet. On inquiring they said 
# ...

# %%
data.type.unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
data.city.unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block'], dtype=object)

# %%
data.cost.unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '1,700', '1,400', '1,350', '2,200', '2,000',
#        '1,800', '1,900', '180', '330', '2,500', '2,100', '3,000', '2,800',
#        '3,400', '50', '40', '1,250', '3,500', '4,000', '2,400', '2,600',
#        '1,450', '70', '3,200', '560', '240', '360', '6,000', '1,050',
#        '2,300'], dtype=object)

# %%
replace = lambda x:x.replace(",","")
p=[]
for cost_val in map(replace,data['cost']):
    cost_val=int(cost_val)
    p.append(cost_val)
data['cost'] = p

# %%
data.head()
# Out:
#               reasturant online_order book_table rating  votes      location  \
# 0                  Jalsa          Yes        Yes    4.1    775  Banashankari
# 1         Spice Elephant          Yes         No    4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No    3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No    3.7     88  Banashankari
# 4          Grand Village           No         No    3.8    166  Basavanagudi
#
#              rest_type                       food_type  cost  \
# 0        Casual Dining  North Indian, Mughlai, Chinese   800
# 1        Casual Dining     Chinese, North Indian, Thai   800
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian   800
# 3          Quick Bites      South Indian, North Indian   300
# 4        Casual Dining        North Indian, Rajasthani   600
#
#                                         reviews_list    type          city
# ...

# %%
data.cost.unique()
# Out:
# array([ 800,  300,  600,  700,  550,  500,  450,  650,  400,  900,  200,
#         750,  150,  850,  100, 1200,  350,  250,  950, 1000, 1500, 1300,
#         199,   80, 1100,  160, 1600,  230,  130, 1700, 1400, 1350, 2200,
#        2000, 1800, 1900,  180,  330, 2500, 2100, 3000, 2800, 3400,   50,
#          40, 1250, 3500, 4000, 2400, 2600, 1450,   70, 3200,  560,  240,
#         360, 6000, 1050, 2300])

# %%
data.duplicated().value_counts()
# Out:
# False    25730
# Name: count, dtype: int64

# %%
data.drop_duplicates(keep="last",inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#               reasturant online_order book_table rating  votes      location  \
# 0                  Jalsa          Yes        Yes    4.1    775  Banashankari
# 1         Spice Elephant          Yes         No    4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No    3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No    3.7     88  Banashankari
# 4          Grand Village           No         No    3.8    166  Basavanagudi
#
#              rest_type                       food_type  cost  \
# 0        Casual Dining  North Indian, Mughlai, Chinese   800
# 1        Casual Dining     Chinese, North Indian, Thai   800
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian   800
# 3          Quick Bites      South Indian, North Indian   300
# 4        Casual Dining        North Indian, Rajasthani   600
#
#                                         reviews_list    type          city
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25730 entries, 0 to 25729
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   reasturant    25730 non-null  object
#  1   online_order  25730 non-null  object
#  2   book_table    25730 non-null  object
#  3   rating        25730 non-null  object
#  4   votes         25730 non-null  int64
#  5   location      25730 non-null  object
#  6   rest_type     25730 non-null  object
#  7   food_type     25730 non-null  object
#  8   cost          25730 non-null  int64
#  9   reviews_list  25730 non-null  object
#  10  type          25730 non-null  object
#  11  city          25730 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 2.4+ MB

# %%
data.to_csv('zomato_clean.csv')
